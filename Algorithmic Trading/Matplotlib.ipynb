# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#Functional method
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Quadratic')
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r')

plt.subplot(2,2,2)
plt.plot(x,y,'b')

plt.subplot(2,2,3)
plt.plot(x,y,'g')

plt.subplot(2,2,4)
plt.plot(x,y,'y')

plt.show()

# %%
# Object Oriented Method
fig=plt.figure()

axes=fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X-axis')
axes.set_ylabel('Y-axis')
axes.set_title('Quadratic')
# Out:
# Text(0.5, 1.0, 'Quadratic')

# %%
fig=plt.figure()

axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.55,0.4,0.3])

axes1.plot(x,y,'r')
axes1.set_xlabel('X-axis')
axes1.set_ylabel('Y-axis')
axes1.set_title('Quadratic')

axes2.plot(x,y,'r')
axes2.set_xlabel('X-axis')
axes2.set_ylabel('Y-axis')
axes2.set_title('Quadratic')
# Out:
# Text(0.5, 1.0, 'Quadratic')

# %%
fig=plt.figure()

axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.2,0.4,0.3])

axes1.plot(x,y,'b')
axes1.set_xlabel('X-axis')
axes1.set_ylabel('Y-axis')
axes1.set_title('Quadratic')

axes2.plot(x,y,'b')
axes2.set_xlabel('X-axis')
axes2.set_ylabel('Y-axis')
axes2.set_title('Quadratic')
# Out:
# Text(0.5, 1.0, 'Quadratic')

# %%
fig=plt.figure()

axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.45,0.2,0.4,0.3])

axes1.plot(x,y,'g')
axes1.set_xlabel('X-axis')
axes1.set_ylabel('Y-axis')
axes1.set_title('Quadratic')

axes2.plot(x,y,'g')
axes2.set_xlabel('X-axis')
axes2.set_ylabel('Y-axis')
axes2.set_title('Quadratic')
# Out:
# Text(0.5, 1.0, 'Quadratic')

# %%
fig=plt.figure()

axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.45,0.55,0.4,0.3])

axes1.plot(x,y,'y')
axes1.set_xlabel('X-axis')
axes1.set_ylabel('Y-axis')
axes1.set_title('Quadratic')

axes2.plot(x,y,'y')
axes2.set_xlabel('X-axis')
axes2.set_ylabel('Y-axis')
axes2.set_title('Quadratic')
# Out:
# Text(0.5, 1.0, 'Quadratic')

# %%
fig=plt.figure()

axes=fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X-axis')
axes.set_ylabel('Y-axis')
axes.set_title('Quadratic')
# Out:
# Text(0.5, 1.0, 'Quadratic')

# %%
fig,axes=plt.subplots(nrows=1,ncols=4)
#axes.plot(x,y)
for current_ax in axes:
    current_ax.plot(x,y)

plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=1,ncols=4)

axes[0].plot(x,y,'r-')
axes[0].set_xlabel('X-axis')
axes[0].set_ylabel('Y-axis')
axes[0].set_title('Quadratic')

axes[1].plot(x,y,'b-')
axes[1].set_xlabel('X-axis')
axes[1].set_ylabel('Y-axis')
axes[1].set_title('Quadratic')

axes[2].plot(x,y,'g-')
axes[2].set_xlabel('X-axis')
axes[2].set_ylabel('Y-axis')
axes[2].set_title('Quadratic')

axes[3].plot(x,y,'y-')
axes[3].set_xlabel('X-axis')
axes[3].set_ylabel('Y-axis')
axes[3].set_title('Quadratic')

plt.tight_layout()

# %%
#Figure Size & DPI

# %%
fig=plt.figure(figsize=(5,2)) #,dpi=100)

ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Quadratic')
# Out:
# Text(0.5, 1.0, 'Quadratic')

# %%
fig,axes=plt.subplots(nrows=1,ncols=4,figsize=(8,4)) #,dpi=100)

axes[0].plot(x,y,'r-')
axes[0].set_xlabel('X-axis')
axes[0].set_ylabel('Y-axis')
axes[0].set_title('Quadratic')

axes[1].plot(x,y,'b-')
axes[1].set_xlabel('X-axis')
axes[1].set_ylabel('Y-axis')
axes[1].set_title('Quadratic')

axes[2].plot(x,y,'g-')
axes[2].set_xlabel('X-axis')
axes[2].set_ylabel('Y-axis')
axes[2].set_title('Quadratic')

axes[3].plot(x,y,'y-')
axes[3].set_xlabel('X-axis')
axes[3].set_ylabel('Y-axis')
axes[3].set_title('Quadratic')

plt.tight_layout()

# %%
fig

# %%
fig.savefig('my_picture.png',dpi=200)

# %%
fig=plt.figure(figsize=(5,2)) #,dpi=100)

ax=fig.add_axes([0,0,1,1])

ax.plot(x,y,label='X squared')
ax.plot(x,x**3,label='X cubed')

ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

ax.set_title('Graphs')

ax.legend()
#ax.legend(loc=(0.1,0.1))

# %%
#Plot Appearance

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=1,alpha=12,ls='-',marker='o'
        ,ms='10',markerfacecolor='yellow',markeredgewidth='3'
        ,markeredgecolor='green')

ax.set_xlim([1.5,5.5])
ax.set_ylim([0,28])
# Out:
# (0, 28)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
#Plot Scatter

# %%
plt.scatter(x,y)

# %%
#Histogram

# %%
from random import sample

# %%
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([12., 10., 11.,  9., 11., 14.,  7., 10., 10.,  6.]),
#  array([ 11. , 108.3, 205.6, 302.9, 400.2, 497.5, 594.8, 692.1, 789.4,
#         886.7, 984. ]),
#  <a list of 10 Patch objects>)

# %%
# Rectangular Box plot

# %%
data = [np.random.normal(0, std, 100)
        for std in range(1, 4)]

# %%
plt.boxplot(data,vert=True,patch_artist=True);
