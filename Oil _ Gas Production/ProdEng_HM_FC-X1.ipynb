# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns  
import matplotlib.pyplot as plt

# might be needed depending on your version of Jupyter
# %matplotlib inline

# %%
df = pd.read_csv('../Oil & Gas Production/Pandey_Ch07_Production_Engineering_Code/data/Well_Monthly_ProdT.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  528 non-null    object
#  1   OIL         528 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.4+ KB

# %%
df.isnull().sum()
# Out:
# START_DATE    0
# OIL           0
# dtype: int64

# %%
df.head()
# Out:
#    START_DATE       OIL
# 0  1974-01-01   7134368
# 1  1974-01-02   9528303
# 2  1974-01-03  12263786
# 3  1974-01-04  13153821
# 4  1974-01-05  12240857

# %%
df
# Out:
#      START_DATE       OIL
# 0    1974-01-01   7134368
# 1    1974-01-02   9528303
# 2    1974-01-03  12263786
# 3    1974-01-04  13153821
# 4    1974-01-05  12240857
# ..          ...       ...
# 523  2017-01-08   8450763
# 524  2017-01-09   8168717
# 525  2017-01-10   8668929
# 526  2017-01-11   8452498
# 527  2017-01-12   8607196
#
# [528 rows x 2 columns]

# %%
df.corr()['OIL'].sort_values()
# Out:
# OIL    1.0
# Name: OIL, dtype: float64

# %%
#df.corr()['GAS'].sort_values()

# %%
#df.corr()['WATER'].sort_values()

# %%
df.corr()
# Out:
#      OIL
# OIL  1.0

# %%
df.describe().transpose()
# Out:
#      count          mean           std        min        25%        50%  \
# OIL  528.0  8.045604e+06  1.848717e+06  2448443.0  6849751.0  8160325.0
#
#             75%         max
# OIL  8837232.25  13429157.0

# %%
from datetime import datetime

# %%
df.index.argmax()
# Out:
# 527

# %%
df.index.max()
# Out:
# 527

# %%
df.index.argmin()
# Out:
# 0

# %%
df.index.min()
# Out:
# 0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=528, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  528 non-null    object
#  1   OIL         528 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.4+ KB

# %%
df['START_DATE']=pd.to_datetime(df['START_DATE'])

# %%
df['START_DATE']
# Out:
# 0     1974-01-01
# 1     1974-01-02
# 2     1974-01-03
# 3     1974-01-04
# 4     1974-01-05
#          ...
# 523   2017-01-08
# 524   2017-01-09
# 525   2017-01-10
# 526   2017-01-11
# 527   2017-01-12
# Name: START_DATE, Length: 528, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  528 non-null    datetime64[ns]
#  1   OIL         528 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 8.4 KB

# %%
type(df['START_DATE'])
# Out:
# pandas.core.series.Series

# %%
df['START_DATE']=df['START_DATE'].apply(pd.to_datetime)

# %%
df.head()
# Out:
#   START_DATE       OIL
# 0 1974-01-01   7134368
# 1 1974-01-02   9528303
# 2 1974-01-03  12263786
# 3 1974-01-04  13153821
# 4 1974-01-05  12240857

# %%
df.set_index('START_DATE',inplace=True)

# %%
df
# Out:
#                  OIL
# START_DATE
# 1974-01-01   7134368
# 1974-01-02   9528303
# 1974-01-03  12263786
# 1974-01-04  13153821
# 1974-01-05  12240857
# ...              ...
# 2017-01-08   8450763
# 2017-01-09   8168717
# 2017-01-10   8668929
# 2017-01-11   8452498
# 2017-01-12   8607196
#
# [528 rows x 1 columns]

# %%
df_rsampl=df.resample(rule='A')

# %%
df_rsampl.mean()
# Out:
#                      OIL
# START_DATE
# 1974-12-31  1.094336e+07
# 1975-12-31  9.677353e+06
# 1976-12-31  1.238384e+07
# 1977-12-31  1.219350e+07
# 1978-12-31  9.631731e+06
# 1979-12-31  9.734584e+06
# 1980-12-31  9.196173e+06
# 1981-12-31  7.920534e+06
# 1982-12-31  6.882836e+06
# 1983-12-31  6.964146e+06
# 1984-12-31  6.701600e+06
# 1985-12-31  6.409274e+06
# 1986-12-31  7.232679e+06
# 1987-12-31  7.358089e+06
# 1988-12-31  7.125255e+06
# 1989-12-31  7.804004e+06
# 1990-12-31  8.662816e+06
# 1991-12-31  9.231862e+06
# 1994-12-31  6.489493e+05
# 1995-12-31  5.740698e+05
# 1996-12-31  7.920798e+05
# 1997-12-31  5.932481e+05
# 1998-12-31  4.689838e+05
# 1999-12-31  1.008647e+06
# 2000-12-31  1.148286e+06
# 2001-12-31  1.692758e+06
# 2002-12-31  9.202077e+05
# 2003-12-31  5.220782e+05
# 2004-12-31  4.128478e+05
# 2005-12-31  1.277204e+06
# 2006-12-31  9.191868e+05
# 2007-12-31  9.330120e+05
# 2008-12-31  4.526042e+05
# ...

# %%
#df=df.replace(0, np.nan)

# %%
#df=df.replace(0, np.nan).dropna(subset=["OIL"], how="all")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 528 entries, 1974-01-01 to 2017-01-12
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   OIL     528 non-null    int64
# dtypes: int64(1)
# memory usage: 8.2 KB

# %%
#df = df.drop('WATER',axis=1)

# %%
#df = df.drop('GAS',axis=1)

# %%
#df = df.drop('UWI',axis=1)

# %%
df
# Out:
#                  OIL
# START_DATE
# 1974-01-01   7134368
# 1974-01-02   9528303
# 1974-01-03  12263786
# 1974-01-04  13153821
# 1974-01-05  12240857
# ...              ...
# 2017-01-08   8450763
# 2017-01-09   8168717
# 2017-01-10   8668929
# 2017-01-11   8452498
# 2017-01-12   8607196
#
# [528 rows x 1 columns]

# %%
df.shift(periods=1).head()
# Out:
#                    OIL
# START_DATE
# 1974-01-01         NaN
# 1974-01-02   7134368.0
# 1974-01-03   9528303.0
# 1974-01-04  12263786.0
# 1974-01-05  13153821.0

# %%
df.shift(periods=-1).tail()
# Out:
#                   OIL
# START_DATE
# 2017-01-08  8168717.0
# 2017-01-09  8668929.0
# 2017-01-10  8452498.0
# 2017-01-11  8607196.0
# 2017-01-12        NaN

# %%
df.shift(periods=-1).head()
# Out:
#                    OIL
# START_DATE
# 1974-01-01   9528303.0
# 1974-01-02  12263786.0
# 1974-01-03  13153821.0
# 1974-01-04  12240857.0
# 1974-01-05  11403237.0

# %%
df.tshift(freq='M').head()
# Out:
# <ipython-input-44-ac6c8a75b133>:1: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   df.tshift(freq='M').head()
#                  OIL
# START_DATE
# 1974-01-31   7134368
# 1974-01-31   9528303
# 1974-01-31  12263786
# 1974-01-31  13153821
# 1974-01-31  12240857

# %%
df.tshift(freq='A').head()
# Out:
# <ipython-input-45-750a8637f102>:1: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   df.tshift(freq='A').head()
#                  OIL
# START_DATE
# 1974-12-31   7134368
# 1974-12-31   9528303
# 1974-12-31  12263786
# 1974-12-31  13153821
# 1974-12-31  12240857

# %%
df['OIL'].plot(figsize=(26,13));

# %%
df.rolling(7).mean().head(14)
# Out:
#                      OIL
# START_DATE
# 1974-01-01           NaN
# 1974-01-02           NaN
# 1974-01-03           NaN
# 1974-01-04           NaN
# 1974-01-05           NaN
# 1974-01-06           NaN
# 1974-01-07  1.126688e+07
# 1974-01-08  1.205206e+07
# 1974-01-09  1.236712e+07
# 1974-01-10  1.201908e+07
# 1974-01-11  1.152319e+07
# 1974-01-12  1.099989e+07
# 1975-01-01  9.847068e+06
# 1975-01-02  8.319158e+06

# %%
df['OIL'].plot()
df.rolling(window=7).mean()['OIL'].plot(figsize=(26,13))
#plt.xlim(left="1975-01-01",right="1980-12-31")
# Out:
# <AxesSubplot:xlabel='START_DATE'>

# %%
df['OIL'].plot()
df.rolling(window=30).mean()['OIL'].plot(figsize=(26,13))
# Out:
# <AxesSubplot:xlabel='START_DATE'>
