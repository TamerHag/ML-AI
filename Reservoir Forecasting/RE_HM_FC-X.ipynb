# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns  
import matplotlib.pyplot as plt

# might be needed depending on your version of Jupyter
# %matplotlib inline

# %%
df = pd.read_csv('../MLOG/Pandey_Ch06_Reservoir_Engineering_Code/data/2015_05.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14065 entries, 0 to 14064
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ReportDate  14065 non-null  object
#  1   API_WELLNO  14065 non-null  float64
#  2   FileNo      14065 non-null  float64
#  3   Company     14065 non-null  object
#  4   WellName    14065 non-null  object
#  5   Quarter     14065 non-null  object
#  6   Section     14065 non-null  float64
#  7   Township    14065 non-null  float64
#  8   Range       14065 non-null  float64
#  9   County      14065 non-null  object
#  10  FieldName   14065 non-null  object
#  11  Pool        14065 non-null  object
#  12  Oil         13887 non-null  float64
#  13  Wtr         13887 non-null  float64
#  14  Days        13887 non-null  float64
#  15  Runs        14065 non-null  float64
#  16  Gas         13887 non-null  float64
#  17  GasSold     14065 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# ReportDate      0
# API_WELLNO      0
# FileNo          0
# Company         0
# WellName        0
# Quarter         0
# Section         0
# Township        0
# Range           0
# County          0
# FieldName       0
# Pool            0
# Oil           178
# Wtr           178
# Days          178
# Runs            0
# Gas           178
# GasSold         0
# Flared        178
# Lat             0
# Long            0
# dtype: int64

# %%
df.head()
# Out:
#   ReportDate    API_WELLNO   FileNo                      Company  \
# 0    05/2015  3.305304e+13  23615.0  MUREX PETROLEUM CORPORATION
# 1    05/2015  3.305304e+13  22021.0         STATOIL OIL & GAS LP
# 2    05/2015  3.305305e+13  25091.0         STATOIL OIL & GAS LP
# 3    05/2015  3.305305e+13  25645.0         STATOIL OIL & GAS LP
# 4    05/2015  3.305305e+13  25092.0         STATOIL OIL & GAS LP
#
#                   WellName Quarter  Section  Township  Range County  ...  \
# 0  AMBER ELIZABETH  36-25H    SESW     36.0     151.0  101.0    MCK  ...
# 1         BILL  14-23 2TFH    SWSW     11.0     151.0  101.0    MCK  ...
# 2           BILL  14-23 3H    NWNE     14.0     151.0  101.0    MCK  ...
# 3         BILL  14-23 4TFH    NWNE     14.0     151.0  101.0    MCK  ...
# 4         BILL  14-23 5TFH    NWNE     14.0     151.0  101.0    MCK  ...
#
#      Pool     Oil      Wtr  Days    Runs     Gas  GasSold  Flared        Lat  \
# ...

# %%
df.tail()
# Out:
#       ReportDate    API_WELLNO   FileNo                          Company  \
# 14060    05/2015  3.308900e+13   9917.0  WHITING OIL AND GAS CORPORATION
# 14061    05/2015  3.300901e+13   2507.0              ENERGYQUEST II, LLC
# 14062    05/2015  3.300901e+13   6347.0              ENERGYQUEST II, LLC
# 14063    05/2015  3.300901e+13   5815.0              ENERGYQUEST II, LLC
# 14064    05/2015  3.300902e+13  13685.0              ENERGYQUEST II, LLC
#
#                        WellName Quarter  Section  Township  Range County  ...  \
# 14060  ZENITH-NEWTON UNIT     2    SESW      3.0     139.0   99.0    STK  ...
# 14061       OBERT LINSTAD     1    SESE     22.0     163.0   79.0    BOT  ...
# 14062                RICE     2    SENW     26.0     163.0   79.0    BOT  ...
# 14063            RICE     23-12    NWSW     23.0     163.0   79.0    BOT  ...
# 14064                RICE     3    NENW     26.0     163.0   79.0    BOT  ...
#
# ...

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['Oil'])
# Out:
# <AxesSubplot:xlabel='Oil'>

# %%
df.corr()
# Out:
#             API_WELLNO    FileNo   Section  Township     Range       Oil  \
# API_WELLNO    1.000000  0.216312 -0.049671  0.233104  0.151966  0.132291
# FileNo        0.216312  1.000000 -0.007208  0.023162  0.134848  0.515175
# Section      -0.049671 -0.007208  1.000000  0.044366 -0.041186  0.005218
# Township      0.233104  0.023162  0.044366  1.000000 -0.563641 -0.025602
# Range         0.151966  0.134848 -0.041186 -0.563641  1.000000  0.046137
# Oil           0.132291  0.515175  0.005218 -0.025602  0.046137  1.000000
# Wtr          -0.025348  0.141448  0.013716 -0.094498  0.082290  0.299805
# Days          0.042283  0.284471 -0.016650 -0.020757  0.017633  0.285270
# Runs          0.135884  0.518328  0.007388 -0.026339  0.046569  0.998819
# Gas           0.144590  0.388897 -0.011236 -0.009734  0.063861  0.756706
# GasSold       0.155030  0.356630 -0.013048  0.013393  0.040420  0.682310
# Flared        0.030666  0.185163  0.013061 -0.061687  0.082803  0.374636
# ...

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.describe().transpose()
# Out:
#               count          mean           std           min           25%  \
# API_WELLNO  14065.0  3.305072e+13  3.090667e+10  3.300700e+13  3.302501e+13
# FileNo      14065.0  1.972511e+04  6.576666e+03  3.500000e+01  1.624900e+04
# Section     14065.0  1.831767e+01  1.045999e+01  1.000000e+00  9.000000e+00
# Township    14065.0  1.516753e+02  7.453554e+00  1.290000e+02  1.480000e+02
# Range       14065.0  9.556417e+01  5.788019e+00  7.600000e+01  9.300000e+01
# Oil         13887.0  2.517969e+03  3.494026e+03 -1.000000e+00  3.070000e+02
# Wtr         13887.0  2.881038e+03  5.630458e+03 -1.000000e+00  3.090000e+02
# Days        13887.0  2.480989e+01  1.092897e+01  0.000000e+00  2.500000e+01
# Runs        14065.0  2.630780e+03  3.692292e+03  0.000000e+00  3.170000e+02
# Gas         13887.0  3.436429e+03  6.207557e+03  0.000000e+00  2.225000e+02
# GasSold     14065.0  2.778462e+03  5.661033e+03  0.000000e+00  0.000000e+00
# ...

# %%
df.corr()['Oil'].sort_values()
# Out:
# Long         -0.050674
# Lat          -0.026578
# Township     -0.025602
# Section       0.005218
# Range         0.046137
# API_WELLNO    0.132291
# Days          0.285270
# Wtr           0.299805
# Flared        0.374636
# FileNo        0.515175
# GasSold       0.682310
# Gas           0.756706
# Runs          0.998819
# Oil           1.000000
# Name: Oil, dtype: float64

# %%
plt.figure(figsize=(12,4))
sns.distplot(df['Oil'],kde=False,bins=40)
# Out:
# <AxesSubplot:xlabel='Oil'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Runs',y='Oil',data=df)
# Out:
# <AxesSubplot:xlabel='Runs', ylabel='Oil'>

# %%
df.groupby('Days')['Oil'].describe()
# Out:
#        count         mean          std   min     25%     50%      75%      max
# Days
# 0.0   1540.0    -0.001299     0.036026  -1.0    0.00     0.0     0.00      0.0
# 1.0    166.0    74.084337   256.854974   0.0    0.00     1.5    27.75   1929.0
# 2.0     68.0   137.926471   345.575890   0.0    4.75    22.0   107.00   2550.0
# 3.0     67.0   325.447761   711.259303   0.0    5.50    53.0   210.00   3669.0
# 4.0     60.0   451.066667  1016.901206   0.0    7.75    45.0   344.75   5496.0
# 5.0     58.0   544.086207   959.007497   0.0   26.75   127.5   417.75   3945.0
# 6.0     53.0   925.679245  1564.164040   0.0   28.00   169.0   847.00   6861.0
# 7.0     59.0  1492.508475  2699.574950   0.0   45.50    96.0  1280.00  12150.0
# 8.0     54.0   624.351852  1122.234230   0.0   51.25   209.5   628.00   6964.0
# 9.0     35.0  1281.200000  2149.019760   0.0  112.00   243.0  1690.00   9119.0
# 10.0    64.0  1265.968750  1684.791165   0.0  131.00   696.0  1633.25   9133.0
# ...

# %%
df.groupby('ReportDate')['Oil'].describe()
# Out:
#               count        mean          std  min    25%     50%     75%  \
# ReportDate
# 05/2015     13887.0  2517.96918  3494.026047 -1.0  307.0  1483.0  3236.0
#
#                 max
# ReportDate
# 05/2015     40368.0

# %%
#plt.figure(figsize=(12,8))
#df.groupby('Days')['Oil'].plot();

# %%
#plt.figure(figsize=(12,8))
#df.groupby('ReportDate')['Oil'].plot();

# %%
#df.groupby('Days').mean()['Oil'].describe(

# %%
#plt.figure(figsize=(12,8))
#f.groupby('Days').mean()['Oil'].plot()

# %%
#df.groupby('ReportDate').mean()['Oil'].describe()

# %%
#df.groupby('API_WELLNO')['Oil'].describe()

# %%
#df.groupby('API_WELLNO')['Oil'].sum().sort_values().tail(10)

# %%
#df.groupby('Oil')['API_WELLNO'].sum().tail(10)

# %%
df.groupby('WellName')['Oil'].sum().sort_values().tail(10)
# Out:
# WellName
# KOALA  4-4-28-4H                30216.0
# HIDATSA  150-94-32C-29H         30673.0
# SHENANDOAH  34-36MBH            32955.0
# MOREAN USA  34-12H              33564.0
# SHENANDOAH  24-36MBH            33606.0
# ANTELOPE  1-23H2                35404.0
# JOHNSON  4-9-4BH                35439.0
# FOREMAN  2-2-1BH                35887.0
# FOREMAN  1-2-1TH                37155.0
# SOFTSHELL  152-94-33C-28H TF    40368.0
# Name: Oil, dtype: float64

# %%
df[['WellName','OilRate']].sort_values('OilRate',ascending = True).groupby(by='OilRate').sum().tail(20)

# %%
df.groupby('Oil')['WellName'].sum().tail(10)
# Out:
# Oil
# 30216.0                KOALA  4-4-28-4H
# 30673.0         HIDATSA  150-94-32C-29H
# 32955.0            SHENANDOAH  34-36MBH
# 33564.0              MOREAN USA  34-12H
# 33606.0            SHENANDOAH  24-36MBH
# 35404.0                ANTELOPE  1-23H2
# 35439.0                JOHNSON  4-9-4BH
# 35887.0                FOREMAN  2-2-1BH
# 37155.0                FOREMAN  1-2-1TH
# 40368.0    SOFTSHELL  152-94-33C-28H TF
# Name: WellName, dtype: object

# %%
#df['OilRate'] = df['Oil'] / df['Days']
#df['OilRate']

# %%
#df.info()

# %%
df.isnull().sum()
# Out:
# ReportDate       0
# API_WELLNO       0
# FileNo           0
# Company          0
# WellName         0
# Quarter          0
# Section          0
# Township         0
# Range            0
# County           0
# FieldName        0
# Pool             0
# Oil            178
# Wtr            178
# Days           178
# Runs             0
# Gas            178
# GasSold          0
# Flared         178
# Lat              0
# Long             0
# OilRate       1716
# dtype: int64

# %%
#df['OilRate'] = df['OilRate'].fillna(0)

# %%
#df['OilRate']

# %%
#df.isnull().sum()

# %%
#df.plot(x='Days', y='OilRate',figsize=(12,8));

# %%
df1 = df[['WellName','OilRate']].sort_values('OilRate',ascending = True).groupby(by='OilRate').sum().tail(20)
df1
# Out:
#                                  WellName
# OilRate
# 1143.193548              JOHNSON  4-9-4BH
# 1143.500000              STATE  3-16-21TH
# 1148.857143      MONARCH   152-94-32D-29H
# 1157.645161              FOREMAN  2-2-1BH
# 1190.750000               HUSKY  33-28 6H
# 1198.548387              FOREMAN  1-2-1TH
# 1201.760000              FOREMAN  1-2-1BH
# 1208.640000              KOALA  4-4-28-4H
# 1211.000000              FOREMAN  6-2-1TH
# 1223.000000            FRISINGER   34X-8H
# 1266.869565    SC-NORMA -  154-98-0706H-7
# 1275.000000            TOMAHAWK   10-3 1H
# 1345.600000  SOFTSHELL  152-94-33C-28H TF
# 1374.000000  HA-THOMPSON-  152-95-1720H-7
# 1398.000000          SIMMENTAL  2-11 2TFH
# 1459.304348            MOREAN USA  34-12H
# 1572.153846                 PIPER  34-12H
# 1735.714286        GULBRAND USA  44-12TFH
# 1822.000000  HA-THOMPSON-  152-95-1720H-8
# 1929.000000          VICTOR USA  34-12TFH

# %%
df2 = df[['WellName','Oil']].sort_values('Oil',ascending = True).groupby(by='Oil').sum().tail(20)
df2
# Out:
#                               WellName
# Oil
# 27664.0       SHENANDOAH  44-36MBH ULW
# 27820.0            TAT  150-94-32D-29H
# 28713.0  BB-BELQUIST-  150-95-1110H-12
# 28754.0      FLATLAND FEDERAL  11-4TFH
# 29101.0               STATE  2-16-21TH
# 29138.0     SC-NORMA -  154-98-0706H-7
# 29618.0                    HAYES  2-6H
# 29673.0           SHENANDOAH  44-36TFH
# 29850.0    VICEROY   152-94-32D-29H TF
# 30044.0               FOREMAN  1-2-1BH
# 30216.0               KOALA  4-4-28-4H
# 30673.0        HIDATSA  150-94-32C-29H
# 32955.0           SHENANDOAH  34-36MBH
# 33564.0             MOREAN USA  34-12H
# 33606.0           SHENANDOAH  24-36MBH
# 35404.0               ANTELOPE  1-23H2
# 35439.0               JOHNSON  4-9-4BH
# 35887.0               FOREMAN  2-2-1BH
# 37155.0               FOREMAN  1-2-1TH
# 40368.0   SOFTSHELL  152-94-33C-28H TF

# %%
dfx = df1.merge(df2, how = 'inner' ,indicator=False)
dfx
# Out:
#                        WellName
# 0              JOHNSON  4-9-4BH
# 1              FOREMAN  2-2-1BH
# 2              FOREMAN  1-2-1TH
# 3              FOREMAN  1-2-1BH
# 4              KOALA  4-4-28-4H
# 5    SC-NORMA -  154-98-0706H-7
# 6  SOFTSHELL  152-94-33C-28H TF
# 7            MOREAN USA  34-12H

# %%
df.loc[df['WellName'] == 'HA-THOMPSON- 152-95-1720H-8']
# Out:
# Empty DataFrame
# Columns: [ReportDate, API_WELLNO, FileNo, Company, WellName, Quarter, Section, Township, Range, County, FieldName, Pool, Oil, Wtr, Days, Runs, Gas, GasSold, Flared, Lat, Long, OilRate]
# Index: []
#
# [0 rows x 22 columns]

# %%
df3 = df[['API_WELLNO','OilRate']].sort_values('OilRate',ascending = True).groupby(by='OilRate').sum().tail(20)
df4 = df[['API_WELLNO','Oil']].sort_values('Oil',ascending = True).groupby(by='Oil').sum().tail(20)

# %%
dfy = df3.merge(df4, how = 'inner' ,indicator=False)
dfy
# Out:
#      API_WELLNO
# 0  3.305306e+13
# 1  3.305306e+13
# 2  3.305306e+13
# 3  3.305306e+13
# 4  3.305306e+13
# 5  3.310504e+13
# 6  3.305306e+13
# 7  3.302503e+13

# %%
df['WellName']
# Out:
# 0         AMBER ELIZABETH  36-25H
# 1                BILL  14-23 2TFH
# 2                  BILL  14-23 3H
# 3                BILL  14-23 4TFH
# 4                BILL  14-23 5TFH
#                    ...
# 14060    ZENITH-NEWTON UNIT     2
# 14061         OBERT LINSTAD     1
# 14062                  RICE     2
# 14063              RICE     23-12
# 14064                  RICE     3
# Name: WellName, Length: 14065, dtype: object

# %%
df['API_WELLNO']
# Out:
# 0        3.305304e+13
# 1        3.305304e+13
# 2        3.305305e+13
# 3        3.305305e+13
# 4        3.305305e+13
#              ...
# 14060    3.308900e+13
# 14061    3.300901e+13
# 14062    3.300901e+13
# 14063    3.300901e+13
# 14064    3.300902e+13
# Name: API_WELLNO, Length: 14065, dtype: float64

# %%
df.sort_values('OilRate',ascending=False).head(10)
# Out:
#       ReportDate    API_WELLNO   FileNo                             Company  \
# 7355     05/2015  3.302503e+13  29003.0                MARATHON OIL COMPANY
# 5996     05/2015  3.305306e+13  28761.0     HESS BAKKEN INVESTMENTS II, LLC
# 7352     05/2015  3.302503e+13  29004.0                MARATHON OIL COMPANY
# 7354     05/2015  3.302503e+13  28262.0                MARATHON OIL COMPANY
# 7353     05/2015  3.302503e+13  28263.0                MARATHON OIL COMPANY
# 7340     05/2015  3.310504e+13  28592.0                        ZAVANNA, LLC
# 5995     05/2015  3.305306e+13  28760.0     HESS BAKKEN INVESTMENTS II, LLC
# 640      05/2015  3.305306e+13  27587.0  ENERPLUS RESOURCES USA CORPORATION
# 4487     05/2015  3.310503e+13  23115.0                        ZAVANNA, LLC
# 12916    05/2015  3.310504e+13  29816.0     HESS BAKKEN INVESTMENTS II, LLC
#
#                            WellName Quarter  Section  Township  Range County  \
# ...

# %%
df.sort_values('Oil',ascending=False).head(10)
# Out:
#       ReportDate    API_WELLNO   FileNo  \
# 640      05/2015  3.305306e+13  27587.0
# 11983    05/2015  3.305306e+13  28933.0
# 11984    05/2015  3.305306e+13  28932.0
# 5512     05/2015  3.305306e+13  28666.0
# 4788     05/2015  3.305304e+13  22820.0
# 6590     05/2015  3.305306e+13  28287.0
# 7353     05/2015  3.302503e+13  28263.0
# 6592     05/2015  3.305306e+13  28289.0
# 11955    05/2015  3.305304e+13  21537.0
# 9761     05/2015  3.305306e+13  27409.0
#
#                                          Company  \
# 640           ENERPLUS RESOURCES USA CORPORATION
# 11983                         QEP ENERGY COMPANY
# 11984                         QEP ENERGY COMPANY
# 5512                          QEP ENERGY COMPANY
# 4788                 CONTINENTAL RESOURCES, INC.
# 6590   BURLINGTON RESOURCES OIL & GAS COMPANY LP
# 7353                        MARATHON OIL COMPANY
# 6592   BURLINGTON RESOURCES OIL & GAS COMPANY LP
# 11955         ENERPLUS RESOURCES USA CORPORATION
# ...

# %%
df.corr()['OilRate'].sort_values()
# Out:
# Long         -0.050511
# Lat          -0.019506
# Township     -0.018621
# Section       0.003440
# Range         0.045510
# API_WELLNO    0.130860
# Days          0.151033
# Wtr           0.271747
# Flared        0.372592
# FileNo        0.485587
# GasSold       0.564246
# Gas           0.677958
# Runs          0.818300
# Oil           0.902244
# OilRate       1.000000
# Name: OilRate, dtype: float64

# %%
df.corr()['Oil'].sort_values()
# Out:
# Long         -0.050674
# Lat          -0.026578
# Township     -0.025602
# Section       0.005218
# Range         0.046137
# API_WELLNO    0.132291
# Days          0.285270
# Wtr           0.299805
# Flared        0.374636
# FileNo        0.515175
# GasSold       0.682310
# Gas           0.756706
# OilRate       0.902244
# Runs          0.998819
# Oil           1.000000
# Name: Oil, dtype: float64

# %%
df = df.drop('Long',axis=1)

# %%
df = df.drop('Lat',axis=1)

# %%
df = df.drop('Township',axis=1)

# %%
df.corr()['Oil'].sort_values()
# Out:
# Section       0.005218
# Range         0.046137
# API_WELLNO    0.132291
# Days          0.285270
# Wtr           0.299805
# Flared        0.374636
# FileNo        0.515175
# GasSold       0.682310
# Gas           0.756706
# OilRate       0.902244
# Runs          0.998819
# Oil           1.000000
# Name: Oil, dtype: float64

# %%
df = df.drop('Quarter',axis=1)

# %%
df = df.drop('County',axis=1)

# %%
df = df.drop('GasSold',axis=1)

# %%
df = df.drop('Flared',axis=1)

# %%
df = df.drop('FileNo',axis=1)

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13887 entries, 0 to 14064
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ReportDate  13887 non-null  object
#  1   API_WELLNO  13887 non-null  float64
#  2   Company     13887 non-null  object
#  3   WellName    13887 non-null  object
#  4   Section     13887 non-null  float64
#  5   Range       13887 non-null  float64
#  6   FieldName   13887 non-null  object
#  7   Pool        13887 non-null  object
#  8   Oil         13887 non-null  float64
#  9   Wtr         13887 non-null  float64
#  10  Days        13887 non-null  float64
#  11  Runs        13887 non-null  float64
#  12  Gas         13887 non-null  float64
#  13  OilRate     13887 non-null  float64
# dtypes: float64(9), object(5)
# memory usage: 1.6+ MB

# %%
df.corr()['Oil'].sort_values()
# Out:
# Section       0.005218
# Range         0.046137
# API_WELLNO    0.132291
# Days          0.285270
# Wtr           0.299805
# Gas           0.756706
# OilRate       0.902244
# Runs          0.998819
# Oil           1.000000
# Name: Oil, dtype: float64

# %%
df = df.drop('Section',axis=1)

# %%
df = df.drop('Range',axis=1)

# %%
df = df.drop('OilRate',axis=1)

# %%
df
# Out:
#       ReportDate    API_WELLNO                          Company  \
# 0        05/2015  3.305304e+13      MUREX PETROLEUM CORPORATION
# 1        05/2015  3.305304e+13             STATOIL OIL & GAS LP
# 2        05/2015  3.305305e+13             STATOIL OIL & GAS LP
# 3        05/2015  3.305305e+13             STATOIL OIL & GAS LP
# 4        05/2015  3.305305e+13             STATOIL OIL & GAS LP
# ...          ...           ...                              ...
# 14060    05/2015  3.308900e+13  WHITING OIL AND GAS CORPORATION
# 14061    05/2015  3.300901e+13              ENERGYQUEST II, LLC
# 14062    05/2015  3.300901e+13              ENERGYQUEST II, LLC
# 14063    05/2015  3.300901e+13              ENERGYQUEST II, LLC
# 14064    05/2015  3.300902e+13              ENERGYQUEST II, LLC
#
#                        WellName      FieldName               Pool     Oil  \
# 0       AMBER ELIZABETH  36-25H      ALEXANDER             BAKKEN  1525.0
# ...

# %%
df['OilRate'] = df['Oil'] / df['Days']
df['OilRate']
# Out:
# 0         52.586207
# 1         45.483871
# 2        179.821429
# 3         78.032258
# 4         24.870968
#             ...
# 14060           NaN
# 14061           NaN
# 14062      0.870968
# 14063      0.741935
# 14064           NaN
# Name: OilRate, Length: 13887, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13887 entries, 0 to 14064
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ReportDate  13887 non-null  object
#  1   API_WELLNO  13887 non-null  float64
#  2   Company     13887 non-null  object
#  3   WellName    13887 non-null  object
#  4   FieldName   13887 non-null  object
#  5   Pool        13887 non-null  object
#  6   Oil         13887 non-null  float64
#  7   Wtr         13887 non-null  float64
#  8   Days        13887 non-null  float64
#  9   Runs        13887 non-null  float64
#  10  Gas         13887 non-null  float64
#  11  OilRate     12349 non-null  float64
# dtypes: float64(7), object(5)
# memory usage: 1.4+ MB

# %%
df
# Out:
#       ReportDate    API_WELLNO                          Company  \
# 0        05/2015  3.305304e+13      MUREX PETROLEUM CORPORATION
# 1        05/2015  3.305304e+13             STATOIL OIL & GAS LP
# 2        05/2015  3.305305e+13             STATOIL OIL & GAS LP
# 3        05/2015  3.305305e+13             STATOIL OIL & GAS LP
# 4        05/2015  3.305305e+13             STATOIL OIL & GAS LP
# ...          ...           ...                              ...
# 14060    05/2015  3.308900e+13  WHITING OIL AND GAS CORPORATION
# 14061    05/2015  3.300901e+13              ENERGYQUEST II, LLC
# 14062    05/2015  3.300901e+13              ENERGYQUEST II, LLC
# 14063    05/2015  3.300901e+13              ENERGYQUEST II, LLC
# 14064    05/2015  3.300902e+13              ENERGYQUEST II, LLC
#
#                        WellName      FieldName               Pool     Oil  \
# 0       AMBER ELIZABETH  36-25H      ALEXANDER             BAKKEN  1525.0
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#       ReportDate    API_WELLNO                          Company  \
# 0        05/2015  3.305304e+13      MUREX PETROLEUM CORPORATION
# 1        05/2015  3.305304e+13             STATOIL OIL & GAS LP
# 2        05/2015  3.305305e+13             STATOIL OIL & GAS LP
# 3        05/2015  3.305305e+13             STATOIL OIL & GAS LP
# 4        05/2015  3.305305e+13             STATOIL OIL & GAS LP
# ...          ...           ...                              ...
# 14052    05/2015  3.308901e+13  WHITING OIL AND GAS CORPORATION
# 14053    05/2015  3.308901e+13  WHITING OIL AND GAS CORPORATION
# 14059    05/2015  3.308900e+13   NEW MILLENNIUM RESOURCES, INC.
# 14062    05/2015  3.300901e+13              ENERGYQUEST II, LLC
# 14063    05/2015  3.300901e+13              ENERGYQUEST II, LLC
#
#                       WellName  FieldName               Pool     Oil      Wtr  \
# 0      AMBER ELIZABETH  36-25H  ALEXANDER             BAKKEN  1525.0   1335.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12349 entries, 0 to 14063
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ReportDate  12349 non-null  object
#  1   API_WELLNO  12349 non-null  float64
#  2   Company     12349 non-null  object
#  3   WellName    12349 non-null  object
#  4   FieldName   12349 non-null  object
#  5   Pool        12349 non-null  object
#  6   Oil         12349 non-null  float64
#  7   Wtr         12349 non-null  float64
#  8   Days        12349 non-null  float64
#  9   Runs        12349 non-null  float64
#  10  Gas         12349 non-null  float64
#  11  OilRate     12349 non-null  float64
# dtypes: float64(7), object(5)
# memory usage: 1.2+ MB

# %%
df.isnull().sum()
# Out:
# ReportDate    0
# API_WELLNO    0
# Company       0
# WellName      0
# FieldName     0
# Pool          0
# Oil           0
# Wtr           0
# Days          0
# Runs          0
# Gas           0
# OilRate       0
# dtype: int64

# %%
df = df.drop('ReportDate',axis=1)

# %%
df = df.drop('Company',axis=1)

# %%
df = df.drop('FieldName',axis=1)

# %%
df['WELLID'] = df['WellName'].apply(lambda WellName:WellName[-5:])

# %%
df['WELLID']
# Out:
# 0        6-25H
# 1         2TFH
# 2        23 3H
# 3         4TFH
# 4         5TFH
#          ...
# 14052    12PH
# 14053    26TFH
# 14059     8-34
# 14062        2
# 14063    23-12
# Name: WELLID, Length: 12349, dtype: object

# %%
df.isnull().sum()
# Out:
# API_WELLNO        0
# WellName      12349
# Pool              0
# Oil               0
# Wtr               0
# Days              0
# Runs              0
# Gas               0
# OilRate           0
# WELLID        11692
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12349 entries, 0 to 14063
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   API_WELLNO  12349 non-null  float64
#  1   WellName    0 non-null      float64
#  2   Pool        12349 non-null  object
#  3   Oil         12349 non-null  float64
#  4   Wtr         12349 non-null  float64
#  5   Days        12349 non-null  float64
#  6   Runs        12349 non-null  float64
#  7   Gas         12349 non-null  float64
#  8   OilRate     12349 non-null  float64
#  9   WELLID      657 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 1.0+ MB

# %%
df = df.drop('WELLID',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12349 entries, 0 to 14063
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   API_WELLNO  12349 non-null  float64
#  1   WellName    0 non-null      float64
#  2   Pool        12349 non-null  object
#  3   Oil         12349 non-null  float64
#  4   Wtr         12349 non-null  float64
#  5   Days        12349 non-null  float64
#  6   Runs        12349 non-null  float64
#  7   Gas         12349 non-null  float64
#  8   OilRate     12349 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 964.8+ KB

# %%
df.isnull().sum()
# Out:
# API_WELLNO        0
# WellName      12349
# Pool              0
# Oil               0
# Wtr               0
# Days              0
# Runs              0
# Gas               0
# OilRate           0
# dtype: int64

# %%
df = df.drop('WellName',axis=1)

# %%
df = df.drop('Pool',axis=1)

# %%
df.isnull().sum()
# Out:
# API_WELLNO    0
# Oil           0
# Wtr           0
# Days          0
# Runs          0
# Gas           0
# OilRate       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/__check_build/__init__.py in <module>
#      43 try:
# ---> 44     from ._check_build import check_build  # noqa
#      45 except ImportError as e:
#
# ImportError: dlopen(/Users/tamerhousseinhag/opt/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/__check_build/_check_build.cpython-37m-darwin.so, 2): Symbol not found: ____chkstk_darwin
#   Referenced from: /Users/tamerhousseinhag/opt/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/__check_build/../.dylibs/libomp.dylib (which was built for Mac OS X 10.15)
#   Expected in: /usr/lib/libSystem.B.dylib
#  in /Users/tamerhousseinhag/opt/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/__check_build/../.dylibs/libomp.dylib
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12349 entries, 0 to 14063
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   API_WELLNO  12349 non-null  float64
#  1   Oil         12349 non-null  float64
#  2   Wtr         12349 non-null  float64
#  3   Days        12349 non-null  float64
#  4   Runs        12349 non-null  float64
#  5   Gas         12349 non-null  float64
#  6   OilRate     12349 non-null  float64
# dtypes: float64(7)
# memory usage: 771.8 KB

# %%
#pd.set_option('display.max_rows',None)

# %%
#df

# %%
#df.drop(df.index[6171],inplace=True)

# %%
#df.drop(df.index[7405],inplace=True)

# %%
#df

# %%
#df.replace([np.inf, -np.inf], np.nan)

# %%
df = df.dropna()

# %%
#df.drop([6171, 7405])

# %%
#df

# %%
X = df.drop('OilRate',axis=1)
y = df['OilRate']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.85)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = MinMaxScaler()

# %%
X_train.shape
# Out:
# (1852, 6)

# %%
X_test.shape
# Out:
# (10495, 6)

# %%
y_train.shape
# Out:
# (1852,)

# %%
y_test.shape
# Out:
# (10495,)

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.models import load_model

# %%
from tensorflow.keras.layers import Dropout

# %%
#model = Sequential()

# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw

# input layer
#model.add(Dense(3,  activation='relu'))
#model.add(Dropout(0.2))

# hidden layer
#model.add(Dense(3, activation='relu'))
#model.add(Dropout(0.2))

# hidden layer
#model.add(Dense(3, activation='relu'))
#model.add(Dropout(0.2))

# output layer
#model.add(Dense(units=1,activation='sigmoid'))

# Compile model
#model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model = Sequential()

model.add(Dense(6,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_test,y_test.values),
          batch_size=128,epochs=50)
# Out:
# Train on 1852 samples, validate on 10495 samples
# Epoch 1/50
# 1852/1852 [==============================] - 1s 697us/sample - loss: 30469.0864 - val_loss: inf
# Epoch 2/50
# 1852/1852 [==============================] - 0s 107us/sample - loss: 30453.3314 - val_loss: inf
# Epoch 3/50
# 1852/1852 [==============================] - 0s 103us/sample - loss: 30436.0534 - val_loss: inf
# Epoch 4/50
# 1852/1852 [==============================] - 0s 102us/sample - loss: 30418.0546 - val_loss: inf
# Epoch 5/50
# 1852/1852 [==============================] - 0s 101us/sample - loss: 30398.1679 - val_loss: inf
# Epoch 6/50
# 1852/1852 [==============================] - 0s 105us/sample - loss: 30376.4049 - val_loss: inf
# Epoch 7/50
# 1852/1852 [==============================] - 0s 102us/sample - loss: 30350.9718 - val_loss: inf
# Epoch 8/50
# 1852/1852 [==============================] - 0s 103us/sample - loss: 30321.9155 - val_loss: inf
# Epoch 9/50
# ...

# %%
#model.fit(x=X_train, 
#          y=y_train.values, 
#          epochs=75,
#          batch_size=256,
#          validation_data=(X_test, y_test.values), 
#          )

# %%
#df

# %%
#df.drop([6171,7405],inplace=None)

# %%
df0=df.drop([6171,7405])

# %%
losses = pd.DataFrame(model.history.history)
losses
# Out:
#              loss  val_loss
# 0    30628.911700       inf
# 1    30622.726503       inf
# 2    30617.472496       inf
# 3    30612.945578       inf
# 4    30609.001708       inf
# ..            ...       ...
# 145   4098.007540       inf
# 146   4077.200261       inf
# 147   4060.103082       inf
# 148   4044.289174       inf
# 149   4026.470157       inf
#
# [150 rows x 2 columns]

# %%
losses.plot()
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([[133.674    ],
#        [226.51253  ],
#        [  5.2270937],
#        ...,
#        [257.74918  ],
#        [416.05728  ],
#        [ 75.1126   ]], dtype=float32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12349 entries, 0 to 14063
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   API_WELLNO  12349 non-null  float64
#  1   Oil         12349 non-null  float64
#  2   Wtr         12349 non-null  float64
#  3   Days        12349 non-null  float64
#  4   Runs        12349 non-null  float64
#  5   Gas         12349 non-null  float64
#  6   OilRate     12349 non-null  float64
# dtypes: float64(7)
# memory usage: 771.8 KB

# %%
#mean_absolute_error(y_test,predictions)
#np.sqrt(mean_squared_error(y_test,predictions))

# %%
#explained_variance_score(y_test,predictions)

# %%
#print(classification_report(y_test,predictions))

# %%
#confusion_matrix(y_test,predictions)

# %%
X = df0.drop('OilRate',axis=1)
y = df0['OilRate']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.85)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train.shape
# Out:
# (1851, 6)

# %%
X_test.shape
# Out:
# (10494, 6)

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score
from sklearn.metrics import classification_report,confusion_matrix

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()

model.add(Dense(6,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_test,y_test.values),
          batch_size=128,epochs=100)
# Out:
# Train on 1851 samples, validate on 10494 samples
# Epoch 1/100
# 1851/1851 [==============================] - 1s 523us/sample - loss: 31101.1340 - val_loss: 30029.5061
# Epoch 2/100
# 1851/1851 [==============================] - 0s 136us/sample - loss: 31086.6635 - val_loss: 30014.2815
# Epoch 3/100
# 1851/1851 [==============================] - 0s 146us/sample - loss: 31069.3583 - val_loss: 29995.6465
# Epoch 4/100
# 1851/1851 [==============================] - 0s 117us/sample - loss: 31048.3783 - val_loss: 29972.5036
# Epoch 5/100
# 1851/1851 [==============================] - 0s 103us/sample - loss: 31021.9602 - val_loss: 29942.8575
# Epoch 6/100
# 1851/1851 [==============================] - 0s 103us/sample - loss: 30987.1596 - val_loss: 29904.1280
# Epoch 7/100
# 1851/1851 [==============================] - 0s 106us/sample - loss: 30942.2626 - val_loss: 29852.8521
# Epoch 8/100
# ...

# %%
losses = pd.DataFrame(model.history.history)
losses
# Out:
#             loss      val_loss
# 0   31101.133967  30029.506076
# 1   31086.663520  30014.281505
# 2   31069.358271  29995.646536
# 3   31048.378332  29972.503557
# 4   31021.960154  29942.857495
# 5   30987.159599  29904.128048
# 6   30942.262568  29852.852123
# 7   30884.075064  29785.870561
# 8   30806.422958  29701.915737
# 9   30709.750541  29594.161845
# 10  30588.794887  29459.322493
# 11  30433.050965  29292.807369
# 12  30242.779396  29069.723324
# 13  29990.612705  28803.066241
# 14  29692.031981  28481.242665
# 15  29331.619395  28102.870305
# 16  28909.611489  27660.546471
# 17  28426.088060  27159.890314
# 18  27877.332434  26596.602321
# 19  27281.987232  25948.267519
# 20  26582.281793  25275.358504
# 21  25860.394147  24537.043254
# 22  25081.298427  23749.751966
# 23  24243.854787  22955.759983
# 24  23399.127201  22116.474980
# 25  22535.796437  21283.356779
# 26  21666.530967  20489.273322
# 27  20848.559160  19728.272206
# 28  20061.611590  19058.854499
# ...

# %%
losses.plot()
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([[ 56.692295],
#        [152.59819 ],
#        [ 33.040356],
#        ...,
#        [ 55.657887],
#        [ 97.51943 ],
#        [ 29.64669 ]], dtype=float32)

# %%
mean_absolute_error(y_test,predictions)
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 78.38836840670388

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.6841543885546058

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
#print(classification_report(y_test,predictions))
#classification_report(y_test,predictions)

# %%
#confusion_matrix(y_test,predictions)
